# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.909913
# Nearest to six: trafford, mathilde, zola, caledonians, clarity, checked, capetian, alcmene,
# Nearest to after: recounted, legend, whedon, flagpole, halley, theological, stalactites, bachelors,
# Nearest to other: protecting, obstructing, hopped, sami, almagro, cip, censuses, indictment,
# Nearest to state: crimson, dil, priam, common, citrate, intercultural, stefan, kirkwood,
# Nearest to from: crass, spee, humoral, licence, heinlein, cereals, fy, mnr,
# Nearest to when: micromachining, saltzer, technological, ebook, lian, shoghi, reinsurance, cytotoxic,
# Nearest to in: involvement, spades, melting, moulin, polski, collectibles, seleucids, drayton,
# Nearest to eight: lettuce, gellius, pretended, discontinue, cunning, playfair, breeds, delighted,
# Nearest to so: renal, remarkable, undirected, rito, namespaces, capoeira, marriageable, carina,
# Nearest to can: publically, cloistered, pregnancy, compensation, hamster, linguistique, aqueduct, adventurer,
# Nearest to use: thrush, screech, usemodwiki, genre, aeschylus, sardaukar, smooth, mcclelland,
# Nearest to if: ward, neva, cdc, novelist, salvation, lisbon, nucleon, barrington,
# Nearest to by: persecuting, away, olson, anzus, hyperbole, millimetre, ramps, cannibal,
# Nearest to over: maynooth, ignoring, hallstatt, dow, headaches, soi, brando, skipping,
# Nearest to this: blockbusters, opulent, perot, edmonton, these, sensation, kroon, blotter,
# Nearest to has: hectic, bhutto, commutativity, locarno, asexual, freie, quine, gorillas,
# Average loss at step 2000: 4.371946
# Average loss at step 4000: 3.869666
# Average loss at step 6000: 3.792370
# Average loss at step 8000: 3.687210
# Average loss at step 10000: 3.617665
# Nearest to six: eight, four, seven, five, three, nine, two, zero,
# Nearest to after: became, in, recounted, sergei, collectibles, palestinian, bachelors, brutality,
# Nearest to other: many, hopped, railhead, godard, holyoke, vinod, booted, substrate,
# Nearest to state: ashley, crimp, offices, crimson, common, dexterity, guilt, priam,
# Nearest to from: in, siegfried, into, mnr, by, informants, ali, slowly,
# Nearest to when: lian, kuomintang, irvin, saltzer, micromachining, virtuosity, hamito, alive,
# Nearest to in: of, after, on, from, with, and, at, pronged,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to so: do, orcs, aise, urls, redding, spoiler, braves, disk,
# Nearest to can: may, would, will, zu, lebesgue, adventurer, might, should,
# Nearest to use: screech, screaming, magnates, thrush, aeschylus, quicksort, genre, decisions,
# Nearest to if: salvation, is, barrington, attains, mikhail, necklace, now, still,
# Nearest to by: earnings, was, hypothesised, onboard, is, with, escu, on,
# Nearest to over: maynooth, headaches, salah, marxist, skipping, ignoring, hallstatt, kundalini,
# Nearest to this: it, the, which, that, these, bastard, visualize, a,
# Nearest to has: is, had, was, have, locarno, hist, skate, weep,
# Average loss at step 12000: 3.603015
# Average loss at step 14000: 3.573623
# Average loss at step 16000: 3.410868
# Average loss at step 18000: 3.457701
# Average loss at step 20000: 3.539264
# Nearest to six: eight, seven, five, nine, three, four, zero, two,
# Nearest to after: when, before, tn, during, became, sergei, from, limes,
# Nearest to other: many, various, substrate, some, erotica, longest, godard, such,
# Nearest to state: ashley, viscous, dexterity, crimp, crimson, elwes, exterminate, ecclestone,
# Nearest to from: into, in, at, siegfried, between, and, after, on,
# Nearest to when: while, kuomintang, hamito, after, saltzer, was, irvin, defender,
# Nearest to in: at, on, from, and, with, for, between, by,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to so: aise, spoiler, urls, disk, johansson, redding, bevel, landed,
# Nearest to can: may, would, will, could, might, should, must, see,
# Nearest to use: screaming, screech, quicksort, owing, magnates, usemodwiki, hypnotized, neon,
# Nearest to if: salvation, is, where, did, ia, because, barrington, when,
# Nearest to by: be, hypothesised, in, escu, onboard, while, with, were,
# Nearest to over: maynooth, therapist, kundalini, headaches, marxist, skipping, brando, janissaries,
# Nearest to this: it, which, equal, a, that, the, any, no,
# Nearest to has: had, have, is, was, hist, earnings, manifested, cdf,
# Average loss at step 22000: 3.506307
# Average loss at step 24000: 3.486918
# Average loss at step 26000: 3.478444
# Average loss at step 28000: 3.485200
# Average loss at step 30000: 3.505108
# Nearest to six: four, eight, seven, five, nine, three, zero, two,
# Nearest to after: before, during, when, in, from, tn, until, limes,
# Nearest to other: various, many, these, such, some, joint, erotica, their,
# Nearest to state: ashley, dexterity, viscous, crimp, explorers, ecclestone, quod, profanity,
# Nearest to from: into, in, after, siegfried, between, on, through, under,
# Nearest to when: if, while, after, where, before, but, for, kuomintang,
# Nearest to in: on, at, from, of, and, after, between, siegfried,
# Nearest to eight: nine, seven, five, six, four, three, zero, two,
# Nearest to so: bevel, too, homers, sd, spoiler, urls, aise, opposes,
# Nearest to can: may, would, will, could, should, must, might, cannot,
# Nearest to use: screaming, usemodwiki, screech, petitcodiac, decisions, parts, aeschylus, nuremberg,
# Nearest to if: when, where, although, because, ia, did, barrington, kekul,
# Nearest to by: hypothesised, been, mustafa, huckleberry, with, while, was, in,
# Nearest to over: maynooth, therapist, islamism, headaches, into, dow, kundalini, tirthankaras,
# Nearest to this: it, which, any, another, visualize, what, that, there,
# Nearest to has: had, have, is, was, plausible, bnf, hist, cdf,
# Average loss at step 32000: 3.504254
# Average loss at step 34000: 3.494148
# Average loss at step 36000: 3.456663
# Average loss at step 38000: 3.301447
# Average loss at step 40000: 3.433438
# Nearest to six: four, five, seven, eight, nine, three, two, zero,
# Nearest to after: before, during, when, tn, retainers, while, grit, limes,
# Nearest to other: various, different, such, including, many, joint, some, distinct,
# Nearest to state: dexterity, ashley, explorers, viscous, fia, bangladeshis, exterminate, ecclestone,
# Nearest to from: into, siegfried, through, in, between, within, after, of,
# Nearest to when: where, before, while, if, after, kuomintang, because, but,
# Nearest to in: of, from, for, strengths, within, with, and, during,
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Nearest to so: it, too, bevel, spoiler, homers, humour, replenish, shostakovich,
# Nearest to can: may, will, would, could, might, should, must, cannot,
# Nearest to use: screech, screaming, ionia, usemodwiki, inpatient, parts, nuremberg, hyi,
# Nearest to if: when, where, because, sanctity, mithraeum, though, selves, ia,
# Nearest to by: hypothesised, been, distributor, as, be, mustafa, huckleberry, onboard,
# Nearest to over: therapist, maynooth, through, into, from, wf, islamism, authorizes,
# Nearest to this: which, it, that, the, any, another, what, emily,
# Nearest to has: had, have, was, is, plausible, karpov, earnings, although,
# Average loss at step 42000: 3.437723
# Average loss at step 44000: 3.455599
# Average loss at step 46000: 3.449926
# Average loss at step 48000: 3.352525
# Average loss at step 50000: 3.381796
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to after: before, during, when, while, from, until, limes, though,
# Nearest to other: various, different, many, some, deshima, including, streamlining, others,
# Nearest to state: ashley, dexterity, explorers, viscous, crimp, bangladeshis, fia, profanity,
# Nearest to from: in, through, into, siegfried, after, between, since, during,
# Nearest to when: while, if, after, where, before, but, though, during,
# Nearest to in: during, within, from, since, on, of, near, at,
# Nearest to eight: six, seven, nine, four, five, three, two, zero,
# Nearest to so: if, chaparral, groupoids, coro, dib, replenish, when, cryptids,
# Nearest to can: may, would, could, will, must, might, should, cannot,
# Nearest to use: hands, screaming, screech, study, ionia, importance, end, hyi,
# Nearest to if: when, where, though, although, because, ia, aliyah, think,
# Nearest to by: hypothesised, huckleberry, was, bogus, under, through, ayla, powder,
# Nearest to over: through, maynooth, therapist, authorizes, islamism, dow, frey, silva,
# Nearest to this: which, it, the, some, prototyping, that, he, lansdowne,
# Nearest to has: had, have, was, is, plausible, earnings, since, karpov,
# Average loss at step 52000: 3.433834
# Average loss at step 54000: 3.427336
# Average loss at step 56000: 3.438008
# Average loss at step 58000: 3.397147
# Average loss at step 60000: 3.393082
# Nearest to six: four, eight, five, nine, seven, three, zero, two,
# Nearest to after: before, during, when, until, while, began, from, although,
# Nearest to other: various, different, many, others, barbour, some, including, streamlining,
# Nearest to state: ashley, dexterity, city, council, explorers, majority, constitutional, viscous,
# Nearest to from: through, into, after, within, between, siegfried, in, alliaceae,
# Nearest to when: if, before, while, although, where, after, during, though,
# Nearest to in: within, during, of, at, siegfried, since, on, from,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to so: too, groupoids, dib, if, mauretania, spoiler, chaparral, opposes,
# Nearest to can: may, could, would, will, might, must, should, cannot,
# Nearest to use: importance, hyi, hands, foreshadowed, nuremberg, most, screaming, ionia,
# Nearest to if: when, where, although, though, because, before, ia, know,
# Nearest to by: hypothesised, huckleberry, ayla, backus, through, from, tito, onboard,
# Nearest to over: through, therapist, around, maynooth, frey, invokes, into, authorizes,
# Nearest to this: it, which, that, the, some, there, what, malraux,
# Nearest to has: had, have, was, is, plausible, hist, describes, having,
# Average loss at step 62000: 3.246068
# Average loss at step 64000: 3.257400
# Average loss at step 66000: 3.404351
# Average loss at step 68000: 3.394878
# Average loss at step 70000: 3.364277
# Nearest to six: eight, seven, nine, four, five, three, zero, two,
# Nearest to after: before, during, when, while, for, until, although, at,
# Nearest to other: various, different, including, others, many, nicolae, hexameter, some,
# Nearest to state: government, ashley, priam, council, adsorption, city, exterminate, explorers,
# Nearest to from: through, into, siegfried, between, under, glowing, within, in,
# Nearest to when: if, while, before, where, though, although, after, because,
# Nearest to in: within, during, on, since, through, at, for, strengths,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to so: too, if, chaparral, dib, groupoids, thus, comfortable, sometimes,
# Nearest to can: may, could, will, would, might, must, should, cannot,
# Nearest to use: importance, entourage, ionia, hyi, amount, study, most, foreshadowed,
# Nearest to if: when, though, where, although, because, before, ia, know,
# Nearest to by: hypothesised, through, bogus, huckleberry, posthumus, be, in, for,
# Nearest to over: through, maynooth, around, therapist, tungsten, authorizes, executioner, invokes,
# Nearest to this: which, it, another, the, that, any, what, there,
# Nearest to has: had, have, is, was, plausible, since, contains, symbolised,
# Average loss at step 72000: 3.379189
# Average loss at step 74000: 3.346387
# Average loss at step 76000: 3.320029
# Average loss at step 78000: 3.354761
# Average loss at step 80000: 3.378469
# Nearest to six: five, seven, four, eight, three, nine, zero, two,
# Nearest to after: before, during, when, while, despite, from, though, upon,
# Nearest to other: various, including, others, many, stint, erotica, preconceptions, some,
# Nearest to state: city, states, council, crimp, ashley, profanity, cyprus, majority,
# Nearest to from: through, into, after, siegfried, within, between, in, across,
# Nearest to when: if, before, after, where, during, while, although, though,
# Nearest to in: within, during, on, since, at, until, around, through,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to so: too, groupoids, if, then, chaparral, when, seeing, comfortable,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to use: nuremberg, importance, entourage, starbucks, study, hyi, amount, omit,
# Nearest to if: when, though, where, because, although, since, before, then,
# Nearest to by: huckleberry, hypothesised, with, through, mustafa, needle, when, dsl,
# Nearest to over: therapist, around, through, tungsten, maynooth, authorizes, executioner, marked,
# Nearest to this: it, which, another, what, the, that, hopeless, informer,
# Nearest to has: had, have, is, was, since, plausible, hashemite, recently,
# Average loss at step 82000: 3.410261
# Average loss at step 84000: 3.411450
# Average loss at step 86000: 3.391374
# Average loss at step 88000: 3.357849
# Average loss at step 90000: 3.368735
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to after: before, during, when, while, despite, until, upon, from,
# Nearest to other: various, including, individual, nicolae, others, different, preconceptions, presidential,
# Nearest to state: city, council, cyprus, crimp, profanity, majority, adsorption, abandonment,
# Nearest to from: through, into, siegfried, within, after, across, between, jousting,
# Nearest to when: if, before, after, while, although, though, where, during,
# Nearest to in: within, during, under, around, near, and, of, between,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to so: if, too, matching, thus, groupoids, when, comfortable, rq,
# Nearest to can: could, may, will, must, would, might, should, cannot,
# Nearest to use: starbucks, importance, hyi, fall, nuremberg, omit, outward, entourage,
# Nearest to if: when, where, since, though, although, because, then, ia,
# Nearest to by: huckleberry, through, hypothesised, mustafa, without, dsl, under, bogus,
# Nearest to over: around, through, therapist, tungsten, maynooth, authorizes, off, into,
# Nearest to this: it, which, the, what, another, some, any, bicoid,
# Nearest to has: had, have, is, was, since, plausible, having, hist,
# Average loss at step 92000: 3.397588
# Average loss at step 94000: 3.254707
# Average loss at step 96000: 3.358908
# Average loss at step 98000: 3.247862
# Average loss at step 100000: 3.357501
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to after: before, during, when, despite, while, although, until, without,
# Nearest to other: various, others, including, phrases, individual, larger, boaz, barbour,
# Nearest to state: city, cyprus, council, adsorption, fia, abandonment, elwes, crimp,
# Nearest to from: through, siegfried, into, within, jousting, glowing, fy, across,
# Nearest to when: if, while, although, though, after, before, where, during,
# Nearest to in: within, during, near, until, at, throughout, on, of,
# Nearest to eight: seven, nine, four, six, five, three, zero, two,
# Nearest to so: then, too, thus, if, when, chaparral, matching, sometimes,
# Nearest to can: could, may, must, would, will, should, might, cannot,
# Nearest to use: omit, outward, importance, starbucks, hyi, nuremberg, dodd, content,
# Nearest to if: when, though, where, since, because, although, then, so,
# Nearest to by: when, huckleberry, without, cormac, bundy, through, hypothesised, rees,
# Nearest to over: through, therapist, around, tungsten, maynooth, julie, cafeteria, invokes,
# Nearest to this: which, it, another, what, some, he, hopeless, backstory,
# Nearest to has: had, have, is, was, since, plausible, richie, contains,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
